# %%
mypath = './data'
files = [f for f in listdir(mypath) if isfile(join(mypath, f))]

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

# %%
def process(file_name):
    file_name = 'data/{}'.format(file_name)
    df = pd.read_csv(file_name)
    print(df.head())
    db.DFtoDB(df, 'pbp')

# %%
files
# Out:
# ['NBA_PBP_2017-18.csv',
#  'NBA_PBP_2019-20.csv',
#  'NBA_PBP_2016-17.csv',
#  'NBA_PBP_2018-19.csv',
#  'NBA_PBP_2020-21.csv',
#  'NBA_PBP_2015-16.csv']

# %%
db.tables
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-fa74f80ed3e1> in <module>
# ----> 1 db.tables
#
# NameError: name 'db' is not defined

# %%
query = '''
SELECT *
FROM public.pbp
WHERE url = '/boxscores/202012220BRK.html';
'''

df = db.DBtoDF(query)

# %%
df['url'].iloc[0]
# Out:
# '/boxscores/202012220BRK.html'

# %% [raw]
# df.info()

# %%
df.describe()
# Out:
#                                  url gametype  \
# count                            514      514
# unique                             1        1
# top     /boxscores/202012220BRK.html  regular
# freq                             514      514
#
#                                  location              date     time  \
# count                                 514               514      514
# unique                                  1                 1        1
# top     Barclays Center Brooklyn New York  December 22 2020  7:00 PM
# freq                                  514               514      514
#
#        winningteam quarter secleft awayteam                   awayplay  ...  \
# count          514     514     514      514                        249  ...
# unique           1       4     295        1                        179  ...
# top            BRK       3     477      GSW  Offensive rebound by Team  ...
# freq           514     133      10      514                         11  ...
#
#        freethrownum              entergame               leavegame  \
# count            55                     41                      41
# unique            3                     26                      19
# top          2 of 2  C. LeVert - leverca01  A. Wiggins - wiggian01
# freq             26                      3                       4
#
#                 turnoverplayer turnovertype turnovercause  \
# count                       38           38            17
# unique                      19            6             1
# top     A. Wiggins - wiggian01     bad pass         steal
# freq                         4           17            17
#
#                turnovercauser       jumpballawayplayer     jumpballhomeplayer  \
# count                      17                        2                      2
# unique                     12                        2                      2
# top     K. Durant - duranke01  K. Bazemore - bazemke01  D. Jordan - jordade01
# freq                        3                        1                      1
#
#                 jumpballposs
# count                      2
# unique                     2
# top     K. Oubre - oubreke01
# freq                       1
#
# [4 rows x 40 columns]

# %%
pd.set_option('display.max_columns', None)
df.head()
# Out:
#                             url gametype                           location  \
# 0  /boxscores/202012220BRK.html  regular  Barclays Center Brooklyn New York
# 1  /boxscores/202012220BRK.html  regular  Barclays Center Brooklyn New York
# 2  /boxscores/202012220BRK.html  regular  Barclays Center Brooklyn New York
# 3  /boxscores/202012220BRK.html  regular  Barclays Center Brooklyn New York
# 4  /boxscores/202012220BRK.html  regular  Barclays Center Brooklyn New York
#
#                date     time winningteam quarter secleft awayteam  \
# 0  December 22 2020  7:00 PM         BRK       1     720      GSW
# 1  December 22 2020  7:00 PM         BRK       1     710      GSW
# 2  December 22 2020  7:00 PM         BRK       1     698      GSW
# 3  December 22 2020  7:00 PM         BRK       1     698      GSW
# 4  December 22 2020  7:00 PM         BRK       1     698      GSW
#
#                                             awayplay awayscore hometeam  \
# 0  Jump ball: J. Wiseman vs. D. Jordan (J. Harris...         0      BRK
# 1                                               None         0      BRK
# 2     Shooting foul by K. Irving (drawn by S. Curry)         0      BRK
# 3                   S. Curry makes free throw 1 of 2         1      BRK
# 4                   S. Curry makes free throw 2 of 2         2      BRK
#
#                            homeplay homescore shooter shottype shotoutcome  \
# 0                              None         0    None     None        None
# 1  Turnover by D. Jordan (bad pass)         0    None     None        None
# 2                              None         0    None     None        None
# 3                              None         0    None     None        None
# 4                              None         0    None     None        None
#
#   shotdist assister blocker  foultype                 fouler  \
# 0     None     None    None      None                   None
# 1     None     None    None      None                   None
# 2     None     None    None  shooting  K. Irving - irvinky01
# 3     None     None    None      None                   None
# 4     None     None    None      None                   None
#
#                  fouled rebounder reboundtype violationplayer violationtype  \
# 0                  None      None        None            None          None
# 1                  None      None        None            None          None
# 2  S. Curry - curryst01      None        None            None          None
# 3                  None      None        None            None          None
# 4                  None      None        None            None          None
#
#   timeoutteam      freethrowshooter freethrowoutcome freethrownum entergame  \
# 0        None                  None             None         None      None
# 1        None                  None             None         None      None
# 2        None                  None             None         None      None
# 3        None  S. Curry - curryst01             make       1 of 2      None
# 4        None  S. Curry - curryst01             make       2 of 2      None
#
#   leavegame         turnoverplayer turnovertype turnovercause turnovercauser  \
# 0      None                   None         None          None           None
# 1      None  D. Jordan - jordade01     bad pass          None           None
# 2      None                   None         None          None           None
# 3      None                   None         None          None           None
# 4      None                   None         None          None           None
#
#        jumpballawayplayer     jumpballhomeplayer           jumpballposs
# 0  J. Wiseman - wisemja01  D. Jordan - jordade01  J. Harris - harrijo01
# 1                    None                   None                   None
# 2                    None                   None                   None
# 3                    None                   None                   None
# 4                    None                   None                   None

# %%
import psycopg2

# Connect to an existing database
conn = psycopg2.connect("dbname=test user=postgres")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-4-067ce2edc30a> in <module>
#       2
#       3 # Connect to an existing database
# ----> 4 conn = psycopg2.connect("dbname=test user=postgres")
#
# ~/Desktop/Cloud/Projects/springboard/env/lib/python3.8/site-packages/psycopg2/__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     120
#     121     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 122     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     123     if cursor_factory is not None:
#     124         conn.cursor_factory = cursor_factory
#
# OperationalError: could not connect to server: No such file or directory
# 	Is the server running locally and accepting
# 	connections on Unix domain socket "/tmp/.s.PGSQL.5432"?

# %%
# !pwd
# Out:
# /Users/taiconley/Desktop/Cloud/Projects/springboard/Final_Project

# %%
import pandas as pd

df = pd.read_csv('data/NBA_PBP_2015-16.csv')

# %%
pd.set_option('display.max_columns', None)

# %%
df.head(10)
# Out:
#                             URL GameType                       Location  \
# 0  /boxscores/201510270ATL.html  regular  Philips Arena Atlanta Georgia
# 1  /boxscores/201510270ATL.html  regular  Philips Arena Atlanta Georgia
# 2  /boxscores/201510270ATL.html  regular  Philips Arena Atlanta Georgia
# 3  /boxscores/201510270ATL.html  regular  Philips Arena Atlanta Georgia
# 4  /boxscores/201510270ATL.html  regular  Philips Arena Atlanta Georgia
# 5  /boxscores/201510270ATL.html  regular  Philips Arena Atlanta Georgia
# 6  /boxscores/201510270ATL.html  regular  Philips Arena Atlanta Georgia
# 7  /boxscores/201510270ATL.html  regular  Philips Arena Atlanta Georgia
# 8  /boxscores/201510270ATL.html  regular  Philips Arena Atlanta Georgia
# 9  /boxscores/201510270ATL.html  regular  Philips Arena Atlanta Georgia
#
#               Date     Time WinningTeam  Quarter  SecLeft AwayTeam  \
# 0  October 27 2015  8:00 PM         DET        1      720      DET
# 1  October 27 2015  8:00 PM         DET        1      701      DET
# 2  October 27 2015  8:00 PM         DET        1      699      DET
# 3  October 27 2015  8:00 PM         DET        1      697      DET
# 4  October 27 2015  8:00 PM         DET        1      681      DET
# 5  October 27 2015  8:00 PM         DET        1      660      DET
# 6  October 27 2015  8:00 PM         DET        1      644      DET
# 7  October 27 2015  8:00 PM         DET        1      627      DET
# 8  October 27 2015  8:00 PM         DET        1      625      DET
# 9  October 27 2015  8:00 PM         DET        1      613      DET
#
#                                             AwayPlay  AwayScore HomeTeam  \
# 0  Jump ball: A. Drummond vs. A. Horford (E. lyas...          0      ATL
# 1  A. Drummond misses 2-pt layup from 1 ft (block...          0      ATL
# 2                                                NaN          0      ATL
# 3                                                NaN          0      ATL
# 4  M. Morris makes 2-pt jump shot from 13 ft (ass...          2      ATL
# 5                                                NaN          2      ATL
# 6  K. Caldwell-Pope makes 2-pt jump shot from 8 f...          4      ATL
# 7                                                NaN          4      ATL
# 8                    Defensive rebound by R. Jackson          4      ATL
# 9        A. Drummond misses 2-pt hook shot from 8 ft          4      ATL
#
#                                             HomePlay  HomeScore  \
# 0                                                NaN          0
# 1                                                NaN          0
# 2                   Defensive rebound by K. Bazemore          0
# 3                 Turnover by K. Bazemore (bad pass)          0
# 4                                                NaN          0
# 5  P. Millsap makes 2-pt jump shot from 12 ft (as...          2
# 6                                                NaN          2
# 7        A. Horford misses 2-pt jump shot from 20 ft          2
# 8                                                NaN          2
# 9                                                NaN          2
#
#                         Shooter        ShotType ShotOutcome  ShotDist  \
# 0                           NaN             NaN         NaN       NaN
# 1       A. Drummond - drumman01      2-pt layup        miss       1.0
# 2                           NaN             NaN         NaN       NaN
# 3                           NaN             NaN         NaN       NaN
# 4         M. Morris - morrima03  2-pt jump shot        make      13.0
# 5        P. Millsap - millspa01  2-pt jump shot        make      12.0
# 6  K. Caldwell-Pope - caldwke01  2-pt jump shot        make       8.0
# 7        A. Horford - horfoal01  2-pt jump shot        miss      20.0
# 8                           NaN             NaN         NaN       NaN
# 9       A. Drummond - drumman01  2-pt hook shot        miss       8.0
#
#                   Assister                 Blocker FoulType Fouler Fouled  \
# 0                      NaN                     NaN      NaN    NaN    NaN
# 1                      NaN  A. Horford - horfoal01      NaN    NaN    NaN
# 2                      NaN                     NaN      NaN    NaN    NaN
# 3                      NaN                     NaN      NaN    NaN    NaN
# 4  A. Drummond - drumman01                     NaN      NaN    NaN    NaN
# 5    K. Korver - korveky01                     NaN      NaN    NaN    NaN
# 6  E. İlyasova - ilyaser01                     NaN      NaN    NaN    NaN
# 7                      NaN                     NaN      NaN    NaN    NaN
# 8                      NaN                     NaN      NaN    NaN    NaN
# 9                      NaN                     NaN      NaN    NaN    NaN
#
#                  Rebounder ReboundType ViolationPlayer ViolationType  \
# 0                      NaN         NaN             NaN           NaN
# 1                      NaN         NaN             NaN           NaN
# 2  K. Bazemore - bazemke01   defensive             NaN           NaN
# 3                      NaN         NaN             NaN           NaN
# 4                      NaN         NaN             NaN           NaN
# 5                      NaN         NaN             NaN           NaN
# 6                      NaN         NaN             NaN           NaN
# 7                      NaN         NaN             NaN           NaN
# 8   R. Jackson - jacksre01   defensive             NaN           NaN
# 9                      NaN         NaN             NaN           NaN
#
#   TimeoutTeam FreeThrowShooter FreeThrowOutcome FreeThrowNum EnterGame  \
# 0         NaN              NaN              NaN          NaN       NaN
# 1         NaN              NaN              NaN          NaN       NaN
# 2         NaN              NaN              NaN          NaN       NaN
# 3         NaN              NaN              NaN          NaN       NaN
# 4         NaN              NaN              NaN          NaN       NaN
# 5         NaN              NaN              NaN          NaN       NaN
# 6         NaN              NaN              NaN          NaN       NaN
# 7         NaN              NaN              NaN          NaN       NaN
# 8         NaN              NaN              NaN          NaN       NaN
# 9         NaN              NaN              NaN          NaN       NaN
#
#   LeaveGame           TurnoverPlayer TurnoverType TurnoverCause  \
# 0       NaN                      NaN          NaN           NaN
# 1       NaN                      NaN          NaN           NaN
# 2       NaN                      NaN          NaN           NaN
# 3       NaN  K. Bazemore - bazemke01     bad pass           NaN
# 4       NaN                      NaN          NaN           NaN
# 5       NaN                      NaN          NaN           NaN
# 6       NaN                      NaN          NaN           NaN
# 7       NaN                      NaN          NaN           NaN
# 8       NaN                      NaN          NaN           NaN
# 9       NaN                      NaN          NaN           NaN
#
#   TurnoverCauser       JumpballAwayPlayer      JumpballHomePlayer  \
# 0            NaN  A. Drummond - drumman01  A. Horford - horfoal01
# 1            NaN                      NaN                     NaN
# 2            NaN                      NaN                     NaN
# 3            NaN                      NaN                     NaN
# 4            NaN                      NaN                     NaN
# 5            NaN                      NaN                     NaN
# 6            NaN                      NaN                     NaN
# 7            NaN                      NaN                     NaN
# 8            NaN                      NaN                     NaN
# 9            NaN                      NaN                     NaN
#
#               JumpballPoss
# 0  E. İlyasova - ilyaser01
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN
# 5                      NaN
# 6                      NaN
# 7                      NaN
# 8                      NaN
# 9                      NaN
