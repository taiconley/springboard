# %%
from dbPostgres import DB
import pandas as pd
from os import listdir
from os.path import isfile, join
import credentials

dbName = 'nba'
userName = credentials.userName
userPass = credentials.userPass
db = DB(userName=userName, userPass=userPass, dataBaseName=dbName)
# Out:
# /home/tai/Desktop/Projects/SpringBoard/env/lib/python3.6/site-packages/psycopg2/__init__.py:144: UserWarning: The psycopg2 wheel package will be renamed from release 2.8; in order to keep installing from binary please use "pip install psycopg2-binary" instead. For details see: <http://initd.org/psycopg/docs/install.html#binary-install-from-pypi>.
#   """)

# %%
query = '''
SELECT *
FROM public.pbp
WHERE url = '/boxscores/202012220BRK.html'
LIMIT 10;
'''

df = db.DBtoDF(query)
df
# Out:
#                             url gametype                           location  \
# 0  /boxscores/202012220BRK.html  regular  Barclays Center Brooklyn New York
# 1  /boxscores/202012220BRK.html  regular  Barclays Center Brooklyn New York
# 2  /boxscores/202012220BRK.html  regular  Barclays Center Brooklyn New York
# 3  /boxscores/202012220BRK.html  regular  Barclays Center Brooklyn New York
# 4  /boxscores/202012220BRK.html  regular  Barclays Center Brooklyn New York
# 5  /boxscores/202012220BRK.html  regular  Barclays Center Brooklyn New York
# 6  /boxscores/202012220BRK.html  regular  Barclays Center Brooklyn New York
# 7  /boxscores/202012220BRK.html  regular  Barclays Center Brooklyn New York
# 8  /boxscores/202012220BRK.html  regular  Barclays Center Brooklyn New York
# 9  /boxscores/202012220BRK.html  regular  Barclays Center Brooklyn New York
#
#                date     time winningteam quarter secleft awayteam  \
# 0  December 22 2020  7:00 PM         BRK       1     720      GSW
# 1  December 22 2020  7:00 PM         BRK       1     710      GSW
# 2  December 22 2020  7:00 PM         BRK       1     698      GSW
# 3  December 22 2020  7:00 PM         BRK       1     698      GSW
# 4  December 22 2020  7:00 PM         BRK       1     698      GSW
# 5  December 22 2020  7:00 PM         BRK       1     682      GSW
# 6  December 22 2020  7:00 PM         BRK       1     671      GSW
# 7  December 22 2020  7:00 PM         BRK       1     649      GSW
# 8  December 22 2020  7:00 PM         BRK       1     631      GSW
# 9  December 22 2020  7:00 PM         BRK       1     625      GSW
#
#                                             awayplay  ... freethrownum  \
# 0  Jump ball: J. Wiseman vs. D. Jordan (J. Harris...  ...         None
# 1                                               None  ...         None
# 2     Shooting foul by K. Irving (drawn by S. Curry)  ...         None
# 3                   S. Curry makes free throw 1 of 2  ...       1 of 2
# 4                   S. Curry makes free throw 2 of 2  ...       2 of 2
# 5                                               None  ...         None
# 6  J. Wiseman makes 2-pt dunk from 1 ft (assist b...  ...         None
# 7                                               None  ...         None
# 8        A. Wiggins misses 3-pt jump shot from 24 ft  ...         None
# 9                                               None  ...         None
#
#   entergame leavegame         turnoverplayer turnovertype turnovercause  \
# 0      None      None                   None         None          None
# 1      None      None  D. Jordan - jordade01     bad pass          None
# 2      None      None                   None         None          None
# 3      None      None                   None         None          None
# 4      None      None                   None         None          None
# 5      None      None                   None         None          None
# 6      None      None                   None         None          None
# 7      None      None                   None         None          None
# 8      None      None                   None         None          None
# 9      None      None                   None         None          None
#
#   turnovercauser      jumpballawayplayer     jumpballhomeplayer  \
# 0           None  J. Wiseman - wisemja01  D. Jordan - jordade01
# 1           None                    None                   None
# 2           None                    None                   None
# 3           None                    None                   None
# 4           None                    None                   None
# 5           None                    None                   None
# 6           None                    None                   None
# 7           None                    None                   None
# 8           None                    None                   None
# 9           None                    None                   None
#
#             jumpballposs
# 0  J. Harris - harrijo01
# 1                   None
# 2                   None
# 3                   None
# 4                   None
# 5                   None
# 6                   None
# 7                   None
# 8                   None
# 9                   None
#
# [10 rows x 40 columns]
