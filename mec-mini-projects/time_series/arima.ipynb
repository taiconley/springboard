# %%
import sys
import numpy
import scipy
import sklearn
import pandas
import statsmodels
import pyramid

# %%
import warnings
import numpy as np
import pandas as pd
import itertools
import matplotlib.pyplot as plt
import seaborn as sns
import scipy
# %matplotlib inline
from matplotlib.pylab import rcParams
import statsmodels.api as sm
from statsmodels.tsa.seasonal import seasonal_decompose
from sklearn import metrics
import pyramid as pm
from pmdarima.arima import auto_arima

# %%
import ssl
ssl._create_default_https_context = ssl._create_unverified_context

# %%
flight_data = sns.load_dataset("flights")

# %%
flight_data.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
flight_data.describe()
# Out:
#               year  passengers
# count   144.000000  144.000000
# mean   1954.500000  280.298611
# std       3.464102  119.966317
# min    1949.000000  104.000000
# 25%    1951.750000  180.000000
# 50%    1954.500000  265.500000
# 75%    1957.250000  360.500000
# max    1960.000000  622.000000

# %%
flight_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   year        144 non-null    int64
#  1   month       144 non-null    category
#  2   passengers  144 non-null    int64
# dtypes: category(1), int64(2)
# memory usage: 2.9 KB

# %%
flight_data_pivot = flight_data.pivot('month', 'year', 'passengers')
flight_data_pivot
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# Dec     118   140   166   194   201   229   278   306   336   337   405   432

# %%
plt.figure(figsize=(15,5))
sns.heatmap(flight_data_pivot, fmt = 'd', cmap="flare", annot=True)
plt.show()

# %%
month = pd.date_range('19490131', periods=144, freq='M')
month
# Out:
# DatetimeIndex(['1949-01-31', '1949-02-28', '1949-03-31', '1949-04-30',
#                '1949-05-31', '1949-06-30', '1949-07-31', '1949-08-31',
#                '1949-09-30', '1949-10-31',
#                ...
#                '1960-03-31', '1960-04-30', '1960-05-31', '1960-06-30',
#                '1960-07-31', '1960-08-31', '1960-09-30', '1960-10-31',
#                '1960-11-30', '1960-12-31'],
#               dtype='datetime64[ns]', length=144, freq='M')

# %%
flight_data['datestamp'] = month
flight_data.head()
# Out:
#    year month  passengers  datastamp  datestamp
# 0  1949   Jan         112 1949-01-31 1949-01-31
# 1  1949   Feb         118 1949-02-28 1949-02-28
# 2  1949   Mar         132 1949-03-31 1949-03-31
# 3  1949   Apr         129 1949-04-30 1949-04-30
# 4  1949   May         121 1949-05-31 1949-05-31

# %%
data = flight_data[['datestamp', 'passengers']]
data.head()
data.describe()
# Out:
#        passengers
# count  144.000000
# mean   280.298611
# std    119.966317
# min    104.000000
# 25%    180.000000
# 50%    265.500000
# 75%    360.500000
# max    622.000000

# %%
data.set_index('datestamp', inplace = True)

# %%
data.head()
# Out:
#             passengers
# datestamp
# 1949-01-31         112
# 1949-02-28         118
# 1949-03-31         132
# 1949-04-30         129
# 1949-05-31         121

# %%
plt.figure(figsize=(15,10))
plt.plot(data)
plt.xlabel("Time")
plt.ylabel("Passengers in 1000")
plt.title("# of Passengers over Time")
# Out:
# Text(0.5, 1.0, '# of Passengers over Time')

# %%
decomposition = seasonal_decompose(data, model = 'multiplicative')

# %%
plt.figure(figsize=(20,10))

trend = decomposition.trend
seasonal = decomposition.seasonal
residual = decomposition.resid

plt.subplot(221)
plt.plot(data, color = '#00b8ff', label='original')
plt.legend(loc='best')

plt.subplot(222)
plt.plot(trend, 'b', label='Trend')
plt.legend(loc='best')

plt.subplot(223)
plt.plot(seasonal, color='#ff00ff', label='Seasonality')
plt.legend(loc='best')

plt.subplot(224)
plt.plot(residual, 'y', label='Residuals')
plt.legend(loc='best')

plt.tight_layout()

# %%
import pmdarima

# %%
from pmdarima.arima.stationarity import ADFTest

# %%
adf_test = ADFTest(alpha=.05)
adf_test.is_stationary(data)
# Out:
# <ipython-input-67-24aa38068d67>:2: DeprecationWarning: is_stationary is deprecated and will be removed in a future release of pmdarima. Use should_diff instead.
#   adf_test.is_stationary(data)
# (0.01, False)

# %%
adf_test.should_diff(data)
# Out:
# (0.01, False)

# %%
train, test = data[:100], data[100:]
train.shape
test.shape
# Out:
# (44, 1)

# %%
plt.plot(train)
plt.plot(test)

# %%
Arima_model = auto_arima(train, start_p=1, start_q=1, max_p=8, max_q=8,
                        start_P=0, start_Q=0, max_P=8, max_Q=8,
                        m=12, seasonal=True, trace=True, d=1, D=1,
                        error_action='warn', suppress_warnings=True,
                        stepwise=True, random_state=20, n_fits=30
)

Arima_model.summary()
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,1,0)[12]             : AIC=647.341, Time=0.24 sec
#  ARIMA(0,1,0)(0,1,0)[12]             : AIC=650.796, Time=0.02 sec
#  ARIMA(1,1,0)(1,1,0)[12]             : AIC=644.203, Time=0.07 sec
#  ARIMA(0,1,1)(0,1,1)[12]             : AIC=644.733, Time=0.11 sec
#  ARIMA(1,1,0)(0,1,0)[12]             : AIC=645.995, Time=0.02 sec
#  ARIMA(1,1,0)(2,1,0)[12]             : AIC=646.172, Time=0.14 sec
#  ARIMA(1,1,0)(1,1,1)[12]             : AIC=646.187, Time=0.12 sec
#  ARIMA(1,1,0)(0,1,1)[12]             : AIC=644.600, Time=0.08 sec
#  ARIMA(1,1,0)(2,1,1)[12]             : AIC=inf, Time=0.96 sec
#  ARIMA(0,1,0)(1,1,0)[12]             : AIC=647.442, Time=0.04 sec
#  ARIMA(2,1,0)(1,1,0)[12]             : AIC=646.085, Time=0.10 sec
#  ARIMA(1,1,1)(1,1,0)[12]             : AIC=645.647, Time=0.09 sec
#  ARIMA(0,1,1)(1,1,0)[12]             : AIC=644.346, Time=0.07 sec
#  ARIMA(2,1,1)(1,1,0)[12]             : AIC=647.580, Time=0.15 sec
#  ARIMA(1,1,0)(1,1,0)[12] intercept   : AIC=645.940, Time=0.14 sec
#
# Best model:  ARIMA(1,1,0)(1,1,0)[12]
# Total fit time: 2.380 seconds
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                                  y   No. Observations:                  100
# Model:             SARIMAX(1, 1, 0)x(1, 1, 0, 12)   Log Likelihood                -319.101
# Date:                            Mon, 18 Oct 2021   AIC                            644.203
# Time:                                    16:24:42   BIC                            651.601
# Sample:                                         0   HQIC                           647.182
#                                             - 100
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.2434      0.097     -2.512      0.012      -0.433      -0.054
# ar.S.L12      -0.2127      0.087     -2.432      0.015      -0.384      -0.041
# sigma2        89.1842     14.080      6.334      0.000      61.587     116.781
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):                 2.43
# Prob(Q):                              0.97   Prob(JB):                         0.30
# Heteroskedasticity (H):               1.32   Skew:                             0.40
# Prob(H) (two-sided):                  0.46   Kurtosis:                         2.81
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
prediction = pd.DataFrame(Arima_model.predict(n_periods=44),
                          index = test.index)
                
prediction.columns = ['Predicted_Passengers']

# %%
prediction
# Out:
#             Predicted_Passengers
# datestamp
# 1957-05-31            353.433649
# 1957-06-30            406.781321
# 1957-07-31            447.984392
# 1957-08-31            438.051605
# 1957-09-30            391.246543
# 1957-10-31            344.585092
# 1957-11-30            309.159969
# 1957-12-31            345.436075
# 1958-01-31            353.798005
# 1958-02-28            341.286867
# 1958-03-31            393.096441
# 1958-04-30            385.947221
# 1958-05-31            391.288635
# 1958-06-30            445.200445
# 1958-07-31            485.934933
# 1958-08-31            476.413240
# 1958-09-30            428.928631
# 1958-10-31            381.769781
# 1958-11-30            346.435080
# 1958-12-31            382.439764
# 1959-01-31            390.937409
# 1959-02-28            378.109597
# 1959-03-31            430.597759
# 1959-04-30            423.267583
# 1959-05-31            428.628615
# 1959-06-30            482.420435
# 1959-07-31            523.254588
# 1959-08-31            513.645458
# 1959-09-30            466.305385
# 1959-10-31            419.252330
# 1959-11-30            383.898396
# 1959-12-31            419.960810
# 1960-01-31            428.429589
# 1960-02-29            415.669133
# 1960-03-31            468.012962
# 1960-04-30            460.721274
# 1960-05-31            466.078134
# 1960-06-30            519.895475
# 1960-07-31            560.708430
# 1960-08-31            551.117897
# 1960-09-30            503.747082
# 1960-10-31            456.671525
# 1960-11-30            421.321682
# 1960-12-31            457.371817

# %%
plt.figure(figsize=(15,10))
plt.plot(train, label = 'Training')
plt.plot(test,label = 'test')
plt.plot(prediction, label = 'Predicted')
plt.legend(loc='upper center')

# %%
test['Predicted_Passengers'] = prediction
test['Error'] = test['passengers'] - test['Predicted_Passengers']
test
# Out:
# <ipython-input-83-5bc49f94416a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['Predicted_Passengers'] = prediction
# <ipython-input-83-5bc49f94416a>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['Error'] = test['passengers'] - test['Predicted_Passengers']
#             passengers  Predicted_Passengers      Error
# datestamp
# 1957-05-31         355            353.433649   1.566351
# 1957-06-30         422            406.781321  15.218679
# 1957-07-31         465            447.984392  17.015608
# 1957-08-31         467            438.051605  28.948395
# 1957-09-30         404            391.246543  12.753457
# 1957-10-31         347            344.585092   2.414908
# 1957-11-30         305            309.159969  -4.159969
# 1957-12-31         336            345.436075  -9.436075
# 1958-01-31         340            353.798005 -13.798005
# 1958-02-28         318            341.286867 -23.286867
# 1958-03-31         362            393.096441 -31.096441
# 1958-04-30         348            385.947221 -37.947221
# 1958-05-31         363            391.288635 -28.288635
# 1958-06-30         435            445.200445 -10.200445
# 1958-07-31         491            485.934933   5.065067
# 1958-08-31         505            476.413240  28.586760
# 1958-09-30         404            428.928631 -24.928631
# 1958-10-31         359            381.769781 -22.769781
# 1958-11-30         310            346.435080 -36.435080
# 1958-12-31         337            382.439764 -45.439764
# 1959-01-31         360            390.937409 -30.937409
# 1959-02-28         342            378.109597 -36.109597
# 1959-03-31         406            430.597759 -24.597759
# 1959-04-30         396            423.267583 -27.267583
# 1959-05-31         420            428.628615  -8.628615
# 1959-06-30         472            482.420435 -10.420435
# 1959-07-31         548            523.254588  24.745412
# 1959-08-31         559            513.645458  45.354542
# 1959-09-30         463            466.305385  -3.305385
# 1959-10-31         407            419.252330 -12.252330
# 1959-11-30         362            383.898396 -21.898396
# 1959-12-31         405            419.960810 -14.960810
# 1960-01-31         417            428.429589 -11.429589
# 1960-02-29         391            415.669133 -24.669133
# 1960-03-31         419            468.012962 -49.012962
# 1960-04-30         461            460.721274   0.278726
# 1960-05-31         472            466.078134   5.921866
# 1960-06-30         535            519.895475  15.104525
# 1960-07-31         622            560.708430  61.291570
# 1960-08-31         606            551.117897  54.882103
# 1960-09-30         508            503.747082   4.252918
# 1960-10-31         461            456.671525   4.328475
# 1960-11-30         390            421.321682 -31.321682
# 1960-12-31         432            457.371817 -25.371817

# %%
plt.figure(figsize=(20,10))
plt.subplot(121)
plt.plot(test.Error, color = '#ff33CC')
plt.title('Error Distribution Over Time')
plt.subplot(122)
scipy.stats.probplot(test.Error, plot=plt)

plt.figure(figsize=(20,10))
pyramid.autocorr_plot
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-84-affc41e27e7f> in <module>
#       7
#       8 plt.figure(figsize=(20,10))
# ----> 9 pm.autocorr_plot(test.Error)
#
# AttributeError: module 'pyramid' has no attribute 'autocorr_plot'
