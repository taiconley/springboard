# %%
from dbPostgres import DB
import pandas as pd
from os import listdir
from os.path import isfile, join
import credentials

dbName = 'nba'  # 'pi.db'
userName = credentials.userName
userPass = credentials.userPass
db = DB(userName=userName, userPass=userPass, dataBaseName=dbName)
# Out:
# /home/tai/Desktop/Projects/SpringBoard/env/lib/python3.6/site-packages/psycopg2/__init__.py:144: UserWarning: The psycopg2 wheel package will be renamed from release 2.8; in order to keep installing from binary please use "pip install psycopg2-binary" instead. For details see: <http://initd.org/psycopg/docs/install.html#binary-install-from-pypi>.
#   """)

# %%
mypath = './data'
files = [f for f in listdir(mypath) if isfile(join(mypath, f))]

# %%
def process(file_name):
    file_name = 'data/{}'.format(file_name)
    df = pd.read_csv(file_name)
    print(df.head())
    db.DFtoDB(df, 'pbp')

# %%
files
# Out:
# ['NBA_PBP_2020-21.csv',
#  'NBA_PBP_2015-16.csv',
#  'NBA_PBP_2018-19.csv',
#  'NBA_PBP_2019-20.csv',
#  'NBA_PBP_2017-18.csv',
#  'NBA_PBP_2016-17.csv']

# %%
db.tables
# Out:
# ['pbp']

# %%
query = '''
SELECT *
FROM public.pbp
WHERE url = '/boxscores/202012220BRK.html';
'''

df = db.DBtoDF(query)

# %%
df['url'].iloc[0]
# Out:
# '/boxscores/202012220BRK.html'

# %% [raw]
# df.info()

# %%
df.describe()
# Out:
#                                  url gametype  \
# count                            514      514
# unique                             1        1
# top     /boxscores/202012220BRK.html  regular
# freq                             514      514
#
#                                  location              date     time  \
# count                                 514               514      514
# unique                                  1                 1        1
# top     Barclays Center Brooklyn New York  December 22 2020  7:00 PM
# freq                                  514               514      514
#
#        winningteam quarter secleft awayteam                   awayplay  ...  \
# count          514     514     514      514                        249  ...
# unique           1       4     295        1                        179  ...
# top            BRK       3     477      GSW  Offensive rebound by Team  ...
# freq           514     133      10      514                         11  ...
#
#        freethrownum              entergame               leavegame  \
# count            55                     41                      41
# unique            3                     26                      19
# top          2 of 2  C. LeVert - leverca01  A. Wiggins - wiggian01
# freq             26                      3                       4
#
#                 turnoverplayer turnovertype turnovercause  \
# count                       38           38            17
# unique                      19            6             1
# top     A. Wiggins - wiggian01     bad pass         steal
# freq                         4           17            17
#
#                turnovercauser       jumpballawayplayer     jumpballhomeplayer  \
# count                      17                        2                      2
# unique                     12                        2                      2
# top     K. Durant - duranke01  K. Bazemore - bazemke01  D. Jordan - jordade01
# freq                        3                        1                      1
#
#                 jumpballposs
# count                      2
# unique                     2
# top     K. Oubre - oubreke01
# freq                       1
#
# [4 rows x 40 columns]

# %%
pd.set_option('display.max_columns', None)
df.head()
# Out:
#                             url gametype                           location  \
# 0  /boxscores/202012220BRK.html  regular  Barclays Center Brooklyn New York
# 1  /boxscores/202012220BRK.html  regular  Barclays Center Brooklyn New York
# 2  /boxscores/202012220BRK.html  regular  Barclays Center Brooklyn New York
# 3  /boxscores/202012220BRK.html  regular  Barclays Center Brooklyn New York
# 4  /boxscores/202012220BRK.html  regular  Barclays Center Brooklyn New York
#
#                date     time winningteam quarter secleft awayteam  \
# 0  December 22 2020  7:00 PM         BRK       1     720      GSW
# 1  December 22 2020  7:00 PM         BRK       1     710      GSW
# 2  December 22 2020  7:00 PM         BRK       1     698      GSW
# 3  December 22 2020  7:00 PM         BRK       1     698      GSW
# 4  December 22 2020  7:00 PM         BRK       1     698      GSW
#
#                                             awayplay awayscore hometeam  \
# 0  Jump ball: J. Wiseman vs. D. Jordan (J. Harris...         0      BRK
# 1                                               None         0      BRK
# 2     Shooting foul by K. Irving (drawn by S. Curry)         0      BRK
# 3                   S. Curry makes free throw 1 of 2         1      BRK
# 4                   S. Curry makes free throw 2 of 2         2      BRK
#
#                            homeplay homescore shooter shottype shotoutcome  \
# 0                              None         0    None     None        None
# 1  Turnover by D. Jordan (bad pass)         0    None     None        None
# 2                              None         0    None     None        None
# 3                              None         0    None     None        None
# 4                              None         0    None     None        None
#
#   shotdist assister blocker  foultype                 fouler  \
# 0     None     None    None      None                   None
# 1     None     None    None      None                   None
# 2     None     None    None  shooting  K. Irving - irvinky01
# 3     None     None    None      None                   None
# 4     None     None    None      None                   None
#
#                  fouled rebounder reboundtype violationplayer violationtype  \
# 0                  None      None        None            None          None
# 1                  None      None        None            None          None
# 2  S. Curry - curryst01      None        None            None          None
# 3                  None      None        None            None          None
# 4                  None      None        None            None          None
#
#   timeoutteam      freethrowshooter freethrowoutcome freethrownum entergame  \
# 0        None                  None             None         None      None
# 1        None                  None             None         None      None
# 2        None                  None             None         None      None
# 3        None  S. Curry - curryst01             make       1 of 2      None
# 4        None  S. Curry - curryst01             make       2 of 2      None
#
#   leavegame         turnoverplayer turnovertype turnovercause turnovercauser  \
# 0      None                   None         None          None           None
# 1      None  D. Jordan - jordade01     bad pass          None           None
# 2      None                   None         None          None           None
# 3      None                   None         None          None           None
# 4      None                   None         None          None           None
#
#        jumpballawayplayer     jumpballhomeplayer           jumpballposs
# 0  J. Wiseman - wisemja01  D. Jordan - jordade01  J. Harris - harrijo01
# 1                    None                   None                   None
# 2                    None                   None                   None
# 3                    None                   None                   None
# 4                    None                   None                   None
