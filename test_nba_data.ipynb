# %%
from dbPostgres import DB
import pandas as pd
from os import listdir
from os.path import isfile, join
import credentials

dbName = 'nba'  # 'pi.db'
userName = credentials.userName
userPass = credentials.userPass
db = DB(userName=userName, userPass=userPass, dataBaseName=dbName)
# Out:
# /home/tai/Desktop/Projects/SpringBoard/env/lib/python3.6/site-packages/psycopg2/__init__.py:144: UserWarning: The psycopg2 wheel package will be renamed from release 2.8; in order to keep installing from binary please use "pip install psycopg2-binary" instead. For details see: <http://initd.org/psycopg/docs/install.html#binary-install-from-pypi>.
#   """)

# %%
mypath = './data'
files = [f for f in listdir(mypath) if isfile(join(mypath, f))]

# %%
def process(file_name):
    file_name = 'data/{}'.format(file_name)
    df = pd.read_csv(file_name)
    print(df.head())
    db.DFtoDB(df, 'pbp')

# %%
files
# Out:
# ['NBA_PBP_2020-21.csv',
#  'NBA_PBP_2015-16.csv',
#  'NBA_PBP_2018-19.csv',
#  'NBA_PBP_2019-20.csv',
#  'NBA_PBP_2017-18.csv',
#  'NBA_PBP_2016-17.csv']

# %%
db.tables
# Out:
# ['pbp']

# %%
query = '''
SELECT *
FROM public.pbp;
'''

df = db.DBtoDF(query)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3040524 entries, 0 to 3040523
# Data columns (total 40 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   url                 object
#  1   gametype            object
#  2   location            object
#  3   date                object
#  4   time                object
#  5   winningteam         object
#  6   quarter             object
#  7   secleft             object
#  8   awayteam            object
#  9   awayplay            object
#  10  awayscore           object
#  11  hometeam            object
#  12  homeplay            object
#  13  homescore           object
#  14  shooter             object
#  15  shottype            object
#  16  shotoutcome         object
#  17  shotdist            object
#  18  assister            object
#  19  blocker             object
#  20  foultype            object
#  21  fouler              object
#  22  fouled              object
#  23  rebounder           object
#  24  reboundtype         object
#  25  violationplayer     object
#  26  violationtype       object
#  27  timeoutteam         object
#  28  freethrowshooter    object
#  29  freethrowoutcome    object
#  30  freethrownum        object
#  31  entergame           object
#  32  leavegame           object
#  33  turnoverplayer      object
#  34  turnovertype        object
#  35  turnovercause       object
#  36  turnovercauser      object
#  37  jumpballawayplayer  object
#  38  jumpballhomeplayer  object
#  39  jumpballposs        object
# dtypes: object(40)
# memory usage: 927.9+ MB

# %%
df.describe()
# Out:
#                                  url gametype  \
# count                        3040524  3040524
# unique                          6600        2
# top     /boxscores/201512180CHI.html  regular
# freq                             695  2852123
#
#                                      location              date     time  \
# count                                 3040524           3040524  3040524
# unique                                     47              1060       25
# top     STAPLES Center Los Angeles California  November 25 2016  8:00 PM
# freq                                   194631              6741   692982
#
#        winningteam  quarter  secleft awayteam                   awayplay  ...  \
# count      3040524  3040524  3040524  3040524                    1537590  ...
# unique          30        8      721       30                     352052  ...
# top            GSW        4        0      GSW  Offensive rebound by Team  ...
# freq        156783   783440    60936   112376                      39885  ...
#
#        freethrownum             entergame             leavegame  \
# count        302084                303263                303263
# unique            7                  1017                   954
# top          1 of 2  P. Mills - millspa02  B. Lopez - lopezbr01
# freq         124482                  1434                  1451
#
#        turnoverplayer turnovertype turnovercause turnovercauser  \
# count          169979       187496        101478         101478
# unique            957          531             4            889
# top              Team     bad pass         steal          steal
# freq             7702        76520         84092          17386
#
#           jumpballawayplayer    jumpballhomeplayer  \
# count                  28190                 10804
# unique                   699                   625
# top     S. Adams - adamsst01  K. Towns - townska01
# freq                     426                   293
#
#                         jumpballposs
# count                          10804
# unique                           657
# top     G. Antetokounmpo - antetgi01
# freq                             190
#
# [4 rows x 40 columns]

# %%
pd.set_option('display.max_columns', None)
df.head()
# Out:
#                             url gametype                           location  \
# 0  /boxscores/202012220BRK.html  regular  Barclays Center Brooklyn New York
# 1  /boxscores/202012220BRK.html  regular  Barclays Center Brooklyn New York
# 2  /boxscores/202012220BRK.html  regular  Barclays Center Brooklyn New York
# 3  /boxscores/202012220BRK.html  regular  Barclays Center Brooklyn New York
# 4  /boxscores/202012220BRK.html  regular  Barclays Center Brooklyn New York
#
#                date     time winningteam quarter secleft awayteam  \
# 0  December 22 2020  7:00 PM         BRK       1     720      GSW
# 1  December 22 2020  7:00 PM         BRK       1     710      GSW
# 2  December 22 2020  7:00 PM         BRK       1     698      GSW
# 3  December 22 2020  7:00 PM         BRK       1     698      GSW
# 4  December 22 2020  7:00 PM         BRK       1     698      GSW
#
#                                             awayplay awayscore hometeam  \
# 0  Jump ball: J. Wiseman vs. D. Jordan (J. Harris...         0      BRK
# 1                                               None         0      BRK
# 2     Shooting foul by K. Irving (drawn by S. Curry)         0      BRK
# 3                   S. Curry makes free throw 1 of 2         1      BRK
# 4                   S. Curry makes free throw 2 of 2         2      BRK
#
#                            homeplay homescore shooter shottype shotoutcome  \
# 0                              None         0    None     None        None
# 1  Turnover by D. Jordan (bad pass)         0    None     None        None
# 2                              None         0    None     None        None
# 3                              None         0    None     None        None
# 4                              None         0    None     None        None
#
#   shotdist assister blocker  foultype                 fouler  \
# 0     None     None    None      None                   None
# 1     None     None    None      None                   None
# 2     None     None    None  shooting  K. Irving - irvinky01
# 3     None     None    None      None                   None
# 4     None     None    None      None                   None
#
#                  fouled rebounder reboundtype violationplayer violationtype  \
# 0                  None      None        None            None          None
# 1                  None      None        None            None          None
# 2  S. Curry - curryst01      None        None            None          None
# 3                  None      None        None            None          None
# 4                  None      None        None            None          None
#
#   timeoutteam      freethrowshooter freethrowoutcome freethrownum entergame  \
# 0        None                  None             None         None      None
# 1        None                  None             None         None      None
# 2        None                  None             None         None      None
# 3        None  S. Curry - curryst01             make       1 of 2      None
# 4        None  S. Curry - curryst01             make       2 of 2      None
#
#   leavegame         turnoverplayer turnovertype turnovercause turnovercauser  \
# 0      None                   None         None          None           None
# 1      None  D. Jordan - jordade01     bad pass          None           None
# 2      None                   None         None          None           None
# 3      None                   None         None          None           None
# 4      None                   None         None          None           None
#
#        jumpballawayplayer     jumpballhomeplayer           jumpballposs
# 0  J. Wiseman - wisemja01  D. Jordan - jordade01  J. Harris - harrijo01
# 1                    None                   None                   None
# 2                    None                   None                   None
# 3                    None                   None                   None
# 4                    None                   None                   None
